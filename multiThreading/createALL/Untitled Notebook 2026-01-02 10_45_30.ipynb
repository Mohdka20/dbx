# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType, TimestampType

data = [
    ("2025-12-09T14:24:30.790+00:00", "2025-12-09T14:24:30.790+00:00", "dev_sql_zos.`ax@@yob1`.tcrrhdr", 437965542, 1396, 0, 802, 437965348, "A01-SXQ1-802-XX69                        ", "01", "01", "2025-11-26", None, "2025-11-26T16:02:17.190+00:00", "2025-11-26T16:02:17.190+00:00", "I", "AX0YYC          ", "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.728+00:00", "1A1E4A32-0BCB-F011-8196-000D3AE89B0B", None),
    ("2025-12-09T14:24:30.790+00:00", "2025-12-09T14:24:30.790+00:00", "dev_sql_zos.`ax@@yob1`.tcrrhdr", 437965542, 1396, 0, 810, 437965348, "A01-SXQ1-802-XX69                        ", "01", "01", "2025-11-26", None, "2025-11-26T16:02:18.315+00:00", "2025-11-26T16:02:18.315+00:00", "I", "AY0YXH          ", "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "201E4A32-0BCB-F011-8196-000D3AE89B0B", None),
    ("2025-12-09T14:24:30.790+00:00", "2025-12-09T14:24:30.790+00:00", "dev_sql_zos.`ax@@yob1`.tcrrhdr", 399514714, 1231, 0, 802, 399511993, "A34-S0802PFX098DEC01                     ", "01", "01", "2025-12-02", None, "2025-12-02T14:25:25.098+00:00", "2025-12-02T14:25:25.098+00:00", "I", "AX0YYC          ", "PT", "2025-12-02T14:25:29.150+00:00", "R", "2025-12-02T19:45:20.759+00:00", "E34F0D6F-B7CF-F011-8197-7C1E525306DB", None),
    ("2025-12-09T14:24:30.790+00:00", "2025-12-09T14:24:30.790+00:00", "dev_sql_zos.`ax@@yob1`.tcrrhdr", 399514714, 1231, 0, 810, 399511993, "A34-S0802PFX098DEC01                     ", "01", "01", "2025-12-02", None, "2025-12-02T14:25:28.653+00:00", "2025-12-02T14:25:28.653+00:00", "I", "AY0YXH          ", "PT", "2025-12-02T14:25:29.150+00:00", "R", "2025-12-02T19:45:21.009+00:00", "E94F0D6F-B7CF-F011-8197-7C1E525306DB", None)
]

schema = StructType([
    StructField("lh_actn_utc_dttm", StringType(), True),
    StructField("data_received_utc_dttm", StringType(), True),
    StructField("source_file_path", StringType(), True),
    StructField("DRV_REQ_NBR", IntegerType(), True),
    StructField("AX_CLNT_NBR", IntegerType(), True),
    StructField("SBRN_PGM_ACNT_NBR", IntegerType(), True),
    StructField("SO_ID", IntegerType(), True),
    StructField("CONV_DRV_REQ_NBR", IntegerType(), True),
    StructField("CONV_SPLY_REQ_ID", StringType(), True),
    StructField("REQ_DB_LOC_CDE", StringType(), True),
    StructField("REQ_STE_CDE", StringType(), True),
    StructField("REQ_STE_DT", StringType(), True),
    StructField("AUDT_USER_ID", StringType(), True),
    StructField("AUDT_INS_TSTMP", StringType(), True),
    StructField("AUDT_TSTMP", StringType(), True),
    StructField("AUDT_ACTN_CDE", StringType(), True),
    StructField("AUDT_PGM_ID", StringType(), True),
    StructField("AUD_CDD_ENTTYP", StringType(), True),
    StructField("AUD_CDD_TSTMP", StringType(), True),
    StructField("AUD_CDD_METHOD", StringType(), True),
    StructField("DW_CLOUD_INSR_DTTM", StringType(), True),
    StructField("DW_CLOUD_UNIQID", StringType(), True),
    StructField("SBRN_PGM_ID", StringType(), True)
])

df = spark.createDataFrame(data, schema)
df = df.withColumn("lh_actn_utc_dttm", current_timestamp())\
    .withColumn("data_received_utc_dttm", current_timestamp())\
    .withColumn("AUDT_TSTMP", current_timestamp())\
    .withColumn("AUDT_INS_TSTMP", current_timestamp())\
    .withColumn("AUD_CDD_TSTMP", current_timestamp())\
    .withColumn("DW_CLOUD_INSR_DTTM", current_timestamp())  
df.write.option("overwriteSchema", "true").format("delta").mode("overwrite").saveAsTable("dev_hub_bronze.lh_ax_idr.tcrrhdr")

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

data_lcl = [
    ("2025-12-09T14:24:30.793+00:00", "2025-12-09T14:24:30.793+00:00", "dev_sql_zos.`ax@@yob1`.tcrrlcl", 437965542, 1396, None, 0, 802, 1, "08", "", "", "A01-", None, "AX0YYA", "2025-11-26T16:02:17.507+00:00", "2025-11-26T16:02:17.507+00:00", "I", "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "1D1E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T14:24:30.793+00:00", "2025-12-09T14:24:30.793+00:00", "dev_sql_zos.`ax@@yob1`.tcrrlcl", 399514714, 1231, None, 0, 802, 1, "08", "", "", "014-", None, "AX0YYA", "2025-12-02T14:25:26.602+00:00", "2025-12-02T14:25:26.602+00:00", "I", "PT", "2025-12-02T14:25:29.150+00:00", "R", "2025-12-02T19:45:20.993+00:00", "E64F0D6F-B7CF-F011-8197-7C1E525306DB")
]

schema_lcl = StructType([
    StructField("lh_actn_utc_dttm", StringType(), True),
    StructField("data_received_utc_dttm", StringType(), True),
    StructField("source_file_path", StringType(), True),
    StructField("DRV_REQ_NBR", IntegerType(), True),
    StructField("AX_CLNT_NBR", IntegerType(), True),
    StructField("SBRN_PGM_ID", StringType(), True),
    StructField("SBRN_PGM_ACNT_NBR", IntegerType(), True),
    StructField("SO_ID", IntegerType(), True),
    StructField("REQ_VERS_NBR", IntegerType(), True),
    StructField("CLNT_FUNC_CDE", StringType(), True),
    StructField("RLTD_CLNT_NAM_LN_2", StringType(), True),
    StructField("RLTD_CLNT_NAM_LN_1", StringType(), True),
    StructField("EXT_CUS_CLNT_ID", StringType(), True),
    StructField("AUDT_USER_ID", StringType(), True),
    StructField("AUDT_PGM_ID", StringType(), True),
    StructField("AUDT_TSTMP", StringType(), True),
    StructField("AUDT_INS_TSTMP", StringType(), True),
    StructField("AUDT_ACTN_CDE", StringType(), True),
    StructField("AUD_CDD_ENTTYP", StringType(), True),
    StructField("AUD_CDD_TSTMP", StringType(), True),
    StructField("AUD_CDD_METHOD", StringType(), True),
    StructField("DW_CLOUD_INSR_DTTM", StringType(), True),
    StructField("DW_CLOUD_UNIQID", StringType(), True)
])

df_lcl = spark.createDataFrame(data_lcl, schema_lcl)

from pyspark.sql.functions import current_timestamp

df_lcl = df_lcl.withColumn("lh_actn_utc_dttm", current_timestamp())\
    .withColumn("data_received_utc_dttm", current_timestamp())\
    .withColumn("AUDT_TSTMP", current_timestamp())\
    .withColumn("AUDT_INS_TSTMP", current_timestamp())\
    .withColumn("AUD_CDD_TSTMP", current_timestamp())\
    .withColumn("DW_CLOUD_INSR_DTTM", current_timestamp())        
               
df_lcl.write.option("overwriteSchema", "true").format("delta").mode("overwrite").saveAsTable("dev_hub_bronze.lh_ax_idr.tcrrlcl")

# %%
sdf = spark.read.table("dev_hub_bronze.lh_ax_idr.tcrrlcl")
sdf.printSchema()

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

data_roo1 = [
    ("2025-12-09T14:24:30.792+00:00", "2025-12-09T14:24:30.792+00:00", "dev_sql_zos.`ax@@yob1`.tcrroo1", 437965542, 1396, None, 0, 802, 1, "09", "A01-            ", "A01-SXQ1-802-XX69                        ", None, None, None, None, None, None, "01", "02", 1, "2025-11-26", None, "AX0YYC          ", "2025-11-26T16:02:17.223+00:00", "2025-11-26T16:02:17.223+00:00", "I", None, None, "2025-11-26", "A01-SXQ1-802-X", None, "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.743+00:00", "1B1E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T14:24:30.792+00:00", "2025-12-09T14:24:30.792+00:00", "dev_sql_zos.`ax@@yob1`.tcrroo1", 437965542, 1396, None, 0, 810, 1, "09", "A01-            ", "A01-SXQ1-802-XX69                        ", None, None, None, None,  None, None, "01", "02", 1, "2025-11-26", None, "AY0YXH          ", "2025-11-26T16:02:18.318+00:00", "2025-11-26T16:02:18.318+00:00", "I", None, None, "2025-11-26", "A01-SXQ1-802-X", None, "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "211E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T14:24:30.792+00:00", "2025-12-09T14:24:30.792+00:00", "dev_sql_zos.`ax@@yob1`.tcrroo1", 399514714, 1231, None, 0, 802, 1, "09", "A34-            ", "A34-SO802PFX098DEC01                     ", None, None, None, None,  None, None, "01", "02", 442744885, "2025-12-02", None, "AX0YYC          ", "2025-12-02T14:25:25.133+00:00", "2025-12-02T14:25:25.133+00:00", "I", None, None, "2025-12-02", "A34-SO802PFX09", None, "PT", "2025-12-02T14:25:29.150+00:00", "R", "2025-12-02T19:45:20.790+00:00", "E44F0D6F-B7CF-F011-8197-7C1E525306DB"),
    ("2025-12-09T14:24:30.792+00:00", "2025-12-09T14:24:30.792+00:00", "dev_sql_zos.`ax@@yob1`.tcrroo1", 399514714, 1231, None, 0, 810, 1, "09", "A34-            ", "A34-SO802PFX098DEC01                     ", None, None, None, None, None, None, "01", "02", 442744885, "2025-12-02", None, "AY0YXH          ", "2025-12-02T14:25:28.655+00:00", "2025-12-02T14:25:28.655+00:00", "I", None, None, "2025-12-02", "A34-SO802PFX09", None, "PT", "2025-12-02T14:25:29.150+00:00", "R", "2025-12-02T19:45:21.009+00:00", "EA4F0D6F-B7CF-F011-8197-7C1E525306DB"),
    ("2025-12-09T14:24:30.792+00:00", "2025-12-09T14:24:30.792+00:00", "dev_sql_zos.`ax@@yob1`.tcrroo1", 399514714, 1231, None, 0, 810, 1, "09", "A34-            ", "A34-SO802PFX098DEC01                     ", None, None, None, None,  None, None, "01", "02", 442744885, "2025-12-02", None, "AY0YXH          ", "2025-12-02T14:25:28.655+00:00", "2025-12-02T14:25:28.655+00:00", "I", None, None, "2025-12-02", "A34-SO802PFX09", None, "UB", "2025-12-02T15:25:58.297+00:00", "R", "2025-12-02T20:25:59.532+00:00", "8696AC1C-BDCF-F011-8197-7C1E525306DB"),
    ("2025-12-09T14:24:30.792+00:00", "2025-12-09T14:24:30.792+00:00", "dev_sql_zos.`ax@@yob1`.tcrroo1", 399514714, 1231, None, 0, 810, 1, "09", "A34-            ", "A34-SO802PFX098DEC01                     ", None, None, None, None,  None, None, "01", "02", 442744885, "2025-12-02", None, "A00YLR          ", "2025-12-02T15:25:58.193+00:00", "2025-12-02T14:25:28.655+00:00", "U", None, None, "2025-12-02", "A34-SO802PFX09", None, "UP", "2025-12-02T15:25:58.297+00:00", "R", "2025-12-02T20:25:59.532+00:00", "8796AC1C-BDCF-F011-8197-7C1E525306DB")
]

schema_roo1 = StructType([
    StructField("lh_actn_utc_dttm", StringType(), True),
    StructField("data_received_utc_dttm", StringType(), True),
    StructField("source_file_path", StringType(), True),
    StructField("DRV_REQ_NBR", IntegerType(), True),
    StructField("AX_CLNT_NBR", IntegerType(), True),
    StructField("SBRN_PGM_ID", StringType(), True),
    StructField("SBRN_PGM_ACNT_NBR", IntegerType(), True),
    StructField("SO_ID", IntegerType(), True),
    StructField("REQ_VERS_NBR", IntegerType(), True),
    StructField("CLNT_REQ_FUNC_TCDE", StringType(), True),
    StructField("EXT_CUS_CLNT_ID", StringType(), True),
    StructField("CLNT_SPLY_REQ_ID", StringType(), True),
    StructField("PAUTH_NBR", StringType(), True),
    StructField("PRSH_GD_IND", StringType(), True),
    StructField("DRIV_WAIT_IND", StringType(), True),
    StructField("RGSTN_SEQ_NBR", StringType(), True),
    StructField("INS_USER_ID", StringType(), True),
    StructField("INS_WLOC_CDE", StringType(), True),
    StructField("CMNCTN_MD_CDE", StringType(), True),
    StructField("CLNT_REQ_SUBM_TCDE", StringType(), True),
    StructField("EDI_REQ_ID", StringType(), True),
    StructField("REQ_INIT_ENT_DT", StringType(), True),
    StructField("AUDT_USER_ID", StringType(), True),
    StructField("AUDT_PGM_ID", StringType(), True),
    StructField("AUDT_TSTMP", StringType(), True),
    StructField("AUDT_INS_TSTMP", StringType(), True),
    StructField("AUDT_ACTN_CDE", StringType(), True),
    StructField("DCMT_BTCH_ID", StringType(), True),
    StructField("REQ_DB_LOC_CDE", StringType(), True),
    StructField("REQ_DB_LOC_DT", StringType(), True),
    StructField("B3_TRANS_NBR", StringType(), True),
    StructField("FOLLOWUP_IND", StringType(), True),
    StructField("AUD_CDD_ENTTYP", StringType(), True),
    StructField("AUD_CDD_TSTMP", StringType(), True),
    StructField("AUD_CDD_METHOD", StringType(), True),
    StructField("DW_CLOUD_INSR_DTTM", StringType(), True),
    StructField("DW_CLOUD_UNIQID", StringType(), True)
])

df_roo1 = spark.createDataFrame(data_roo1, schema_roo1)

from pyspark.sql.functions import current_timestamp

df_roo1 = df_roo1.withColumn("lh_actn_utc_dttm", current_timestamp())\
    .withColumn("data_received_utc_dttm", current_timestamp())\
    .withColumn("AUDT_TSTMP", current_timestamp())\
    .withColumn("AUDT_INS_TSTMP", current_timestamp())\
    .withColumn("AUD_CDD_TSTMP", current_timestamp())\
    .withColumn("DW_CLOUD_INSR_DTTM", current_timestamp())

df_roo1.write.option("overwriteSchema", "true").format("delta").mode("overwrite").saveAsTable("dev_hub_bronze.lh_ax_idr.tcrroo1")

# %%
df.printSchema()

# %%
from pyspark.sql.types import StructType, StructField, StringType, IntegerType

data_tcrstat = [
    ("2025-12-09T15:38:45.188+00:00", "2025-12-09T15:38:45.188+00:00", "dev_sql_zos.`ax@@yob1`.tcrstat", 437965542, 1396, None, 0, 802, 1, "02", "2025-11-26T16:02:17.312+00:00", "9999-12-31", "2025-11-26", "02", None, None, None, None, "AX0Y5C  AXYL   ", "2025-11-26T16:02:17.312+00:00", "I", 0, "2025-11-26T16:02:17.312+00:00", None, None,  "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.743+00:00", "1C1E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T15:38:45.188+00:00", "2025-12-09T15:38:45.188+00:00", "dev_sql_zos.`ax@@yob1`.tcrstat", 437965542, 1396, None, 0, 802, 1, "02", "2025-11-26T16:02:17.955+00:00", "9999-12-31", "2025-11-26", "01", None, None, None, None, "AX0Y3T  AXYL   ", "2025-11-26T16:02:17.955+00:00", "I", None, "2025-11-26T16:02:17.955+00:00", None, None,  "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "1E1E4A32-0BCB-F011-8196-000D3AE89B0B")
    ,
    ("2025-12-09T15:38:45.188+00:00", "2025-12-09T15:38:45.188+00:00", "dev_sql_zos.`ax@@yob1`.tcrstat", 437965542, 1396, None, 0, 802, 1, "16", "2025-11-26T16:02:18.075+00:00", "9999-12-31", "2025-11-26", "03", "02",  None, None, None, "AX0Y8L  AXYL   ", "2025-11-26T16:02:18.075+00:00", "I", 0, "2025-11-26T16:02:18.075+00:00", None, None,   "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "1F1E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T15:38:45.188+00:00", "2025-12-09T15:38:45.188+00:00", "dev_sql_zos.`ax@@yob1`.tcrstat", 437965542, 1396, None, 0, 810, 1, "22", "2025-11-26T16:02:18.320+00:00", "9999-12-31", "2025-11-26", "03", "02", None, None,  "AY0YXH  ", "AY0YXH  AXYL   ", "2025-11-26T16:02:18.320+00:00", "I", 0, "2025-11-26T16:02:18.320+00:00",  None, None,  "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "221E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T15:38:45.188+00:00", "2025-12-09T15:38:45.188+00:00", "dev_sql_zos.`ax@@yob1`.tcrstat", 437965542, 1396, None, 0, 810, 1, "02", "2025-11-26T16:02:18.321+00:00", "9999-12-31", "2025-11-26", "01", "01", None, None,"AY0YXH  ", "AY0YXH  AXYL   ", "2025-11-26T16:02:18.321+00:00", "I", 0, "2025-11-26T16:02:18.321+00:00",  None, None,"PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "231E4A32-0BCB-F011-8196-000D3AE89B0B"),
    ("2025-12-09T15:38:45.188+00:00", "2025-12-09T15:38:45.188+00:00", "dev_sql_zos.`ax@@yob1`.tcrstat", 437965542, 1396, None, 0, 810, 1, "02", "2025-11-26T16:02:18.321+00:00", "9999-12-31", "2025-11-26", "02", "02", None, None, "AY0YXH  ", "AY0YXH  AXYL   ", "2025-11-26T16:02:18.321+00:00", "I", 0, "2025-11-26T16:02:18.321+00:00",  None, None,  "PT", "2025-11-26T16:02:18.573+00:00", "R", "2025-11-26T21:02:20.759+00:00", "241E4A32-0BCB-F011-8196-000D3AE89B0B")
]

schema_tcrstat = StructType([
    StructField("lh_actn_utc_dttm", StringType(), True),
    StructField("data_received_utc_dttm", StringType(), True),
    StructField("source_file_path", StringType(), True),
    StructField("DRV_REQ_NBR", IntegerType(), True),
    StructField("AX_CLNT_NBR", IntegerType(), True),
    StructField("SBRN_PGM_ID", StringType(), True),
    StructField("SBRN_PGM_ACNT_NBR", IntegerType(), True),
    StructField("SO_ID", IntegerType(), True),
    StructField("REQ_VERS_NBR", IntegerType(), True),
    StructField("CLNT_REQ_SCDE", StringType(), True),
    StructField("AUDT_INS_TSTMP", StringType(), True),
    StructField("STAT_XDT", StringType(), True),
    StructField("STAT_EDT", StringType(), True),
    StructField("CLNT_REQ_STAT_TCDE", StringType(), True),
    StructField("REQ_STAT_CAT_CDE", StringType(), True),
    StructField("REQ_STAT_RCDE", StringType(), True),
    StructField("OP_CELL_TCDE", StringType(), True),
    StructField("AUDT_USER_ID", StringType(), True),
    StructField("AUDT_PGM_ID", StringType(), True),
    StructField("AUDT_TSTMP", StringType(), True),
    StructField("AUDT_ACTN_CDE", StringType(), True),
    StructField("RCVR_IND", IntegerType(), True),
    StructField("ORIG_REQ_INS_TSTMP", StringType(), True),
    StructField("INS_USER_ID", StringType(), True),
    StructField("INS_WLOC_CDE", StringType(), True),
    StructField("AUD_CDD_ENTTYP", StringType(), True),
    StructField("AUD_CDD_TSTMP", StringType(), True),
    StructField("AUD_CDD_METHOD", StringType(), True),
    StructField("DW_CLOUD_INSR_DTTM", StringType(), True),
    StructField("DW_CLOUD_UNIQID", StringType(), True)
])

df_tcrstat = spark.createDataFrame(data_tcrstat, schema_tcrstat)
df_tcrstat.write.option("overwriteSchema", "true").format("delta").mode("overwrite").saveAsTable("dev_hub_bronze.lh_ax_idr.tcrstat")

# %%
# %sql
create catalog dev_hub_silver

# %%
# Create all 4 tables in silver by copying from bronze
tables = ["tcrrhdr", "tcrrlcl", "tcrroo1", "tcrstat"]
for tbl in tables:
    spark.sql(f"""
        CREATE TABLE IF NOT EXISTS dev_hub_silver.lh_ax_idr.{tbl}
        USING DELTA
        AS SELECT * FROM dev_hub_bronze.lh_ax_idr.{tbl}
    """)
