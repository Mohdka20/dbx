# %%
# %sql
select * from samples.tpcds_sf1000.item

# %%
# %sql
select * from samples.tpcds_sf1000.inventory

# %%
# %sql
select * from samples.tpcds_sf1000.inventory
inner join samples.tpcds_sf1000.item
on inventory.inv_item_sk = item.i_item_sk
