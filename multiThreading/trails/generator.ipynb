# %%
import pyspark.sql.functions as f
from pyspark.sql.functions import lit, col
import json

# %%
df_tables = spark.sql("""
    SELECT table_catalog, table_schema, table_name
    FROM dev_hub_silver.information_schema.tables
    WHERE table_catalog = 'dev_hub_silver'
    AND
    table_schema = 'lh_ax_idr'
""")

tables = []
for i in df_tables.collect():
    tables.append(i[2])
print(tables)

# %%
pk_dict = []

for row in df_tables.select("table_name").collect():
    pk_dict.append(row["table_name"])

print(pk_dict)

# %%
dbutils.jobs.taskValues.set(key="pk_dict", value=pk_dict)
